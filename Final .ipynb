# %%
import pandas as pd
import csv

# %%
malaria = "clean_malaria_file copy.csv"
temp = "GlobalLandTemperaturesByCountry.csv"
populations = "Historical Populations by Country.csv"

# %%
malaria_cases_df = pd.read_csv(malaria, encoding = "ISO-8859-1")
population_df = pd.read_csv(populations,encoding = "ISO-8859-1")
ClimateChangeCountryYearly_df = pd.read_csv(temp, encoding = "ISO-8859-1")
ClimateChangeCountryYearly_df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294  Ã
# land
# 1  1743-12-01                 NaN                            NaN  Ã
# land
# 2  1744-01-01                 NaN                            NaN  Ã
# land
# 3  1744-02-01                 NaN                            NaN  Ã
# land
# 4  1744-03-01                 NaN                            NaN  Ã
# land

# %%
frames = [malaria_cases_df, population_df, ClimateChangeCountryYearly_df]
result = pd.concat(frames)
result.head(50)
# Out:
#    1985 1990 1995         2000         2001         2002         2003  \
# 0   NaN  NaN  NaN    1,110,165    1,125,250    1,140,055    1,155,105
# 1   NaN  NaN  NaN   13,925,000   14,385,000   14,887,000   15,421,000
# 2   NaN  NaN  NaN    6,949,000    7,175,000    7,415,000    7,666,000
# 3   NaN  NaN  NaN      728,325      739,945      750,735      760,695
# 4   NaN  NaN  NaN   11,608,000   11,946,000   12,296,000   12,659,000
# 5   NaN  NaN  NaN    3,403,740    3,487,890    3,589,380    3,704,640
# 6   NaN  NaN  NaN   13,618,440   13,979,250   14,348,610   14,725,665
# 7   NaN  NaN  NaN       57,460       58,630       59,670       60,710
# 8   NaN  NaN  NaN    3,638,000    3,704,000    3,767,000    3,830,000
# 9   NaN  NaN  NaN    7,429,395    7,715,795    8,019,200    8,333,345
# 10  NaN  NaN  NaN      512,160      525,740      539,320      552,900
# 11  NaN  NaN  NaN    3,126,000    3,206,000    3,284,000    3,363,000
# ...

# %%
# Starter code for merging two dataframes
malaria_table = pd.merge(malaria_cases_df, population_df, on=['Countries', 'Year'], how="outer")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'Countries'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
#maleria_table
merge_table = pd.merge(ClimateChangeCountryYearly_df, maleria_table, on=['Country', 'Year'], how="outer")
merge_table_df.head()

# Calc percent of actual malaria cases 
#percent =  / population * 100
#print(percent)

#.loc[]
