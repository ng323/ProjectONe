# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file = "Malaria.csv"

malaria_file = pd.read_csv(file, encoding = 'latin-1')
malaria_file.head()
# Out:
#   Countries                                         Indicators  \
# 0       NaN                                                NaN
# 1   Algeria                      Population at risk of malaria
# 2    Angola                      Population at risk of malaria
# 3     Benin  Public domestic sources of spending on Infecti...
# 4     Benin                      Population at risk of malaria
#
#                Unnamed: 2        2000        2001        2002        2003  \
# 0                     NaN       Value       Value       Value       Value
# 1                     NaN   1,110,165   1,125,250   1,140,055   1,155,105
# 2                     NaN  13,925,000  14,385,000  14,887,000  15,421,000
# 3  in million current US$         NaN         NaN         NaN         NaN
# 4                     NaN   6,949,000   7,175,000   7,415,000   7,666,000
#
#          2004        2005        2006        2007        2008        2009  \
# ...

# %%
malaria_file.drop(['Unnamed: 2'], axis=1, inplace = True)
malaria_file.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-4e25fe17ee5d> in <module>()
# ----> 1 malaria_file.drop(['Unnamed: 2'], axis=1, inplace = True)
#       2 malaria_file.drop(['Indicators'], axis=1, inplace = True)
#       3 malaria_file.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
malaria_cases = malaria_file.dropna(how='any')
malaria_cases.head()
# Out:
#       Countries                     Indicators        2000        2001  \
# 1       Algeria  Population at risk of malaria   1,110,165   1,125,250
# 2        Angola  Population at risk of malaria  13,925,000  14,385,000
# 4         Benin  Population at risk of malaria   6,949,000   7,175,000
# 6      Botswana  Population at risk of malaria     728,325     739,945
# 8  Burkina Faso  Population at risk of malaria  11,608,000  11,946,000
#
#          2002        2003        2004        2005        2006        2007  \
# 1   1,140,055   1,155,105   1,171,135   1,188,635   1,207,745   1,228,395
# 2  14,887,000  15,421,000  15,977,000  16,544,000  17,122,000  17,713,000
# 4   7,415,000   7,666,000   7,923,000   8,182,000   8,444,000   8,707,000
# 6     750,735     760,695     769,825     778,540     786,840     794,725
# 8  12,296,000  12,659,000  13,034,000  13,422,000  13,822,000  14,235,000
#
#          2008        2009        2010        2011        2012        2013  \
# ...

# %%
malaria_cases.drop(['Indicators'], axis=1, inplace = True)
print(malaria_cases)
# Out:
#                                  Countries         2000         2001  \
# 1                                  Algeria    1,110,165    1,125,250
# 2                                   Angola   13,925,000   14,385,000
# 4                                    Benin    6,949,000    7,175,000
# 6                                 Botswana      728,325      739,945
# 8                             Burkina Faso   11,608,000   11,946,000
# 10                                 Burundi    3,403,740    3,487,890
# 11                                Cameroon   13,618,440   13,979,250
# 12                  Cabo Verde Republic of       57,460       58,630
# 13                Central African Republic    3,638,000    3,704,000
# 14                                    Chad    7,429,395    7,715,795
# 15                                 Comoros      512,160      525,740
# 16                                   Congo    3,126,000    3,206,000
# 18                           Côte d'Ivoire   16,131,000   16,420,000
# ...

# %%
malaria_cases = pd.DataFrame(malaria_cases)
to_numerica(malaria_cases["2000"]
malaria_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 1 to 130
# Data columns (total 17 columns):
# Countries    96 non-null object
# 2000         96 non-null object
# 2001         96 non-null object
# 2002         96 non-null object
# 2003         96 non-null object
# 2004         96 non-null object
# 2005         96 non-null object
# 2006         96 non-null object
# 2007         96 non-null object
# 2008         96 non-null object
# 2009         96 non-null object
# 2010         96 non-null object
# 2011         96 non-null object
# 2012         96 non-null object
# 2013         96 non-null object
# 2014         96 non-null object
# 2015         96 non-null object
# dtypes: object(17)
# memory usage: 13.5+ KB

# %%
#clean_malaria_file.to_csv("clean_malaria_file.csv", index=False, header=True)

# %%
pd.melt(malaria_cases, id_vars='Countries', value_vars=["2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015"])
# Out:
#                                   Countries variable          value
# 0                                   Algeria     2000      1,110,165
# 1                                    Angola     2000     13,925,000
# 2                                     Benin     2000      6,949,000
# 3                                  Botswana     2000        728,325
# 4                              Burkina Faso     2000     11,608,000
# 5                                   Burundi     2000      3,403,740
# 6                                  Cameroon     2000     13,618,440
# 7                    Cabo Verde Republic of     2000         57,460
# 8                  Central African Republic     2000      3,638,000
# 9                                      Chad     2000      7,429,395
# 10                                  Comoros     2000        512,160
# 11                                    Congo     2000      3,126,000
# 12                            Côte d'Ivoire     2000     16,131,000
# ...

# %%
india = clean_malaria_file.loc[clean_malaria_file["Countries"]=="India", "2000"]
print(india)
# Out:
# 112    922,401,870
# Name: 2000, dtype: object

# %%
x_axis = np.arange(2000,2001,1)
print(x_axis)
# Out:
# [2000]

# %%
plt.plot(x_axis, india)
plt.show()
